# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 635

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}"# YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"   # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]# YOUR CODE HERE
        city_lng = city_weather["coord"]["lon"] # YOUR CODE HERE
        city_max_temp = city_weather["main"]["temp_max"] # YOUR CODE HERE
        city_humidity = city_weather["main"]["humidity"] # YOUR CODE HERE
        city_clouds = city_weather["clouds"]["all"] # YOUR CODE HERE
        city_wind = city_weather["wind"]["speed"] # YOUR CODE HERE
        city_country = city_weather["sys"]["country"] # YOUR CODE HERE
        city_date = city_weather["dt"] # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | guerrero negro
# Processing Record 5 of Set 1 | vitim
# Processing Record 6 of Set 1 | requena
# Processing Record 7 of Set 1 | shache
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 1 | shimoda
# Processing Record 19 of Set 1 | rocha
# Processing Record 20 of Set 1 | south lake tahoe
# Processing Record 21 of Set 1 | namatanai
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | la sarre
# Processing Record 26 of Set 1 | bauchi
# Processing Record 27 of Set 1 | henties bay
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | saint-pierre
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | tahta
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | faya
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | januaria
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 1 | kununurra
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | roma
# Processing Record 43 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | paracatu
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | makubetsu
# Processing Record 48 of Set 1 | rabo de peixe
# Processing Record 49 of Set 1 | monrovia
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 0 of Set 2 | gorom-gorom
# Processing Record 1 of Set 2 | tezu
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | hovd
# Processing Record 5 of Set 2 | lima
# Processing Record 6 of Set 2 | pacific grove
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | camrose
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | lilongwe
# Processing Record 12 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | necochea
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | sao jose da coroa grande
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | hvolsvollur
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | tura
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | tucuman
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | chicama
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | dve mogili
# Processing Record 29 of Set 2 | sirawai
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | udachnyy
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | nemuro
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | port hedland
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | cascais
# Processing Record 38 of Set 2 | inhambane
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | tommot
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 2 | chiredzi
# Processing Record 44 of Set 2 | matara
# Processing Record 45 of Set 2 | soyo
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | acarau
# Processing Record 48 of Set 2 | mogadishu
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 0 of Set 3 | saskylakh
# Processing Record 1 of Set 3 | batticaloa
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | khuzhir
# Processing Record 4 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | miri
# Processing Record 15 of Set 3 | teahupoo
# Processing Record 16 of Set 3 | kissidougou
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | provins
# Processing Record 19 of Set 3 | santa isabel do rio negro
# Processing Record 20 of Set 3 | praia da vitoria
# Processing Record 21 of Set 3 | harindanga
# Processing Record 22 of Set 3 | amapa
# Processing Record 23 of Set 3 | roura
# Processing Record 24 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | road town
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | smithers
# Processing Record 30 of Set 3 | punta arenas
# Processing Record 31 of Set 3 | hay river
# Processing Record 32 of Set 3 | jumla
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | mount isa
# Processing Record 35 of Set 3 | timmins
# Processing Record 36 of Set 3 | walvis bay
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | mudgee
# Processing Record 39 of Set 3 | kollam
# Processing Record 40 of Set 3 | wanxian
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | xai-xai
# Processing Record 45 of Set 3 | shelburne
# Processing Record 46 of Set 3 | sesheke
# Processing Record 47 of Set 3 | laguna de perlas
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | santa rosa
# Processing Record 0 of Set 4 | sur
# Processing Record 1 of Set 4 | isangel
# Processing Record 2 of Set 4 | cape town
# Processing Record 3 of Set 4 | kavaratti
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | dombarovskiy
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | qui nhon
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | ha giang
# Processing Record 10 of Set 4 | tuburan
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | bud
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | burdur
# Processing Record 16 of Set 4 | castro
# Processing Record 17 of Set 4 | snasa
# Processing Record 18 of Set 4 | royan
# Processing Record 19 of Set 4 | dingle
# Processing Record 20 of Set 4 | taoudenni
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | yeppoon
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | olafsvik
# Processing Record 26 of Set 4 | auki
# Processing Record 27 of Set 4 | la baneza
# Processing Record 28 of Set 4 | fairfield
# Processing Record 29 of Set 4 | duiwelskloof
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | lac-megantic
# Processing Record 33 of Set 4 | cauquenes
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | kamogawa
# Processing Record 36 of Set 4 | tanete
# Processing Record 37 of Set 4 | los andes
# Processing Record 38 of Set 4 | kysyl-syr
# Processing Record 39 of Set 4 | paris
# Processing Record 40 of Set 4 | moron
# Processing Record 41 of Set 4 | gao
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | jaguaruna
# Processing Record 44 of Set 4 | avarua
# Processing Record 45 of Set 4 | evensk
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 48 of Set 4 | stefanesti
# Processing Record 49 of Set 4 | kyshtovka
# Processing Record 0 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | storm lake
# Processing Record 2 of Set 5 | cutro
# Processing Record 3 of Set 5 | saldanha
# Processing Record 4 of Set 5 | rach gia
# Processing Record 5 of Set 5 | chaupal
# Processing Record 6 of Set 5 | camargo
# Processing Record 7 of Set 5 | norrtalje
# Processing Record 8 of Set 5 | grootfontein
# Processing Record 9 of Set 5 | chit baragaon
# City not found. Skipping...
# Processing Record 10 of Set 5 | chatham
# Processing Record 11 of Set 5 | axim
# Processing Record 12 of Set 5 | lazaro cardenas
# Processing Record 13 of Set 5 | mantua
# Processing Record 14 of Set 5 | moindou
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | dharchula
# Processing Record 18 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 5 | nishihara
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | innisfail
# Processing Record 22 of Set 5 | tabuk
# Processing Record 23 of Set 5 | great falls
# Processing Record 24 of Set 5 | bredasdorp
# Processing Record 25 of Set 5 | alwar
# Processing Record 26 of Set 5 | diego de almagro
# Processing Record 27 of Set 5 | kinsale
# Processing Record 28 of Set 5 | cayenne
# Processing Record 29 of Set 5 | copiapo
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | coahuayana
# Processing Record 32 of Set 5 | ust-kut
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | blackfoot
# Processing Record 36 of Set 5 | mitsamiouli
# Processing Record 37 of Set 5 | tuktoyaktuk
# Processing Record 38 of Set 5 | pisco
# Processing Record 39 of Set 5 | hervey bay
# Processing Record 40 of Set 5 | scottsbluff
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | we
# City not found. Skipping...
# Processing Record 44 of Set 5 | basavakalyan
# Processing Record 45 of Set 5 | manono
# Processing Record 46 of Set 5 | sovetskiy
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | khandyga
# Processing Record 49 of Set 5 | tonekabon
# Processing Record 0 of Set 6 | craig
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | norman wells
# Processing Record 3 of Set 6 | fairbanks
# Processing Record 4 of Set 6 | lac-au-saumon
# Processing Record 5 of Set 6 | xining
# Processing Record 6 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 6 | grand gaube
# Processing Record 8 of Set 6 | swellendam
# Processing Record 9 of Set 6 | sibot
# Processing Record 10 of Set 6 | ucluelet
# Processing Record 11 of Set 6 | nacunday
# City not found. Skipping...
# Processing Record 12 of Set 6 | acari
# Processing Record 13 of Set 6 | praia
# Processing Record 14 of Set 6 | zemetchino
# Processing Record 15 of Set 6 | sarkand
# Processing Record 16 of Set 6 | saint-philippe
# Processing Record 17 of Set 6 | maumere
# Processing Record 18 of Set 6 | sorland
# Processing Record 19 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 6 | moa
# Processing Record 21 of Set 6 | lisala
# Processing Record 22 of Set 6 | abnub
# Processing Record 23 of Set 6 | chimbote
# Processing Record 24 of Set 6 | peniche
# Processing Record 25 of Set 6 | nalut
# Processing Record 26 of Set 6 | ahipara
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | senador jose porfirio
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | jinchang
# Processing Record 31 of Set 6 | cartagena
# Processing Record 32 of Set 6 | fujin
# Processing Record 33 of Set 6 | souris
# Processing Record 34 of Set 6 | andarab
# City not found. Skipping...
# Processing Record 35 of Set 6 | lakes entrance
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | nehe
# Processing Record 38 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 6 | kodinsk
# Processing Record 40 of Set 6 | dinard
# Processing Record 41 of Set 6 | warmbad
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | hastings
# Processing Record 44 of Set 6 | umm kaddadah
# Processing Record 45 of Set 6 | te anau
# Processing Record 46 of Set 6 | floro
# Processing Record 47 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 6 | nekrasovskoye
# Processing Record 49 of Set 6 | hofn
# Processing Record 0 of Set 7 | ulkan
# Processing Record 1 of Set 7 | krasnyy chikoy
# Processing Record 2 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | zhongshu
# Processing Record 5 of Set 7 | bubaque
# Processing Record 6 of Set 7 | mani
# Processing Record 7 of Set 7 | kerema
# Processing Record 8 of Set 7 | tocopilla
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | saucillo
# Processing Record 12 of Set 7 | krasyukovskaya
# Processing Record 13 of Set 7 | istok
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | shakiso
# Processing Record 16 of Set 7 | luena
# Processing Record 17 of Set 7 | yar-sale
# Processing Record 18 of Set 7 | hargeysa
# Processing Record 19 of Set 7 | aitape
# Processing Record 20 of Set 7 | yaan
# Processing Record 21 of Set 7 | jining
# Processing Record 22 of Set 7 | karasjok
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | tolmezzo
# Processing Record 27 of Set 7 | manta
# Processing Record 28 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 7 | khakhea
# Processing Record 30 of Set 7 | huilong
# Processing Record 31 of Set 7 | huarmey
# Processing Record 32 of Set 7 | emerald
# Processing Record 33 of Set 7 | flinders
# Processing Record 34 of Set 7 | bambous virieux
# Processing Record 35 of Set 7 | kuzino
# Processing Record 36 of Set 7 | roald
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 7 | balikpapan
# Processing Record 40 of Set 7 | okhotsk
# Processing Record 41 of Set 7 | newport
# Processing Record 42 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 7 | bitkine
# Processing Record 44 of Set 7 | riyadh
# Processing Record 45 of Set 7 | sao filipe
# Processing Record 46 of Set 7 | matay
# Processing Record 47 of Set 7 | lar
# Processing Record 48 of Set 7 | pitimbu
# Processing Record 49 of Set 7 | karla
# Processing Record 0 of Set 8 | tianpeng
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | altay
# Processing Record 3 of Set 8 | lorengau
# Processing Record 4 of Set 8 | kibaya
# Processing Record 5 of Set 8 | beni suef
# Processing Record 6 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 8 | amatitan
# Processing Record 8 of Set 8 | luang prabang
# Processing Record 9 of Set 8 | prince rupert
# Processing Record 10 of Set 8 | kudahuvadhoo
# Processing Record 11 of Set 8 | yamada
# Processing Record 12 of Set 8 | port blair
# Processing Record 13 of Set 8 | kilindoni
# Processing Record 14 of Set 8 | chkalovskoye
# Processing Record 15 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 8 | ust-kuyga
# Processing Record 17 of Set 8 | ghanzi
# Processing Record 18 of Set 8 | ambositra
# Processing Record 19 of Set 8 | sombrerete
# Processing Record 20 of Set 8 | tibati
# Processing Record 21 of Set 8 | praya
# Processing Record 22 of Set 8 | kathmandu
# Processing Record 23 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | sola
# Processing Record 27 of Set 8 | tuyen quang
# Processing Record 28 of Set 8 | coquimbo
# Processing Record 29 of Set 8 | matagami
# Processing Record 30 of Set 8 | sioux lookout
# Processing Record 31 of Set 8 | teguldet
# Processing Record 32 of Set 8 | soddy-daisy
# Processing Record 33 of Set 8 | hadishahr
# Processing Record 34 of Set 8 | teneguiban
# City not found. Skipping...
# Processing Record 35 of Set 8 | strezhevoy
# Processing Record 36 of Set 8 | almaznyy
# Processing Record 37 of Set 8 | cameron park
# Processing Record 38 of Set 8 | honningsvag
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 41 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 8 | norden
# Processing Record 43 of Set 8 | livingstonia
# Processing Record 44 of Set 8 | nova olinda do norte
# Processing Record 45 of Set 8 | najran
# Processing Record 46 of Set 8 | hanmer springs
# Processing Record 47 of Set 8 | visby
# Processing Record 48 of Set 8 | coleraine
# Processing Record 49 of Set 8 | shetpe
# Processing Record 0 of Set 9 | fare
# Processing Record 1 of Set 9 | macamic
# Processing Record 2 of Set 9 | madang
# Processing Record 3 of Set 9 | roebourne
# Processing Record 4 of Set 9 | linxia
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | aanekoski
# Processing Record 7 of Set 9 | svetlaya
# Processing Record 8 of Set 9 | shuyskoye
# Processing Record 9 of Set 9 | ambulu
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | luocheng
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | tecoanapa
# Processing Record 14 of Set 9 | aklavik
# Processing Record 15 of Set 9 | husavik
# Processing Record 16 of Set 9 | kisangani
# Processing Record 17 of Set 9 | nioro
# Processing Record 18 of Set 9 | vangaindrano
# Processing Record 19 of Set 9 | abu dhabi
# Processing Record 20 of Set 9 | faanui
# Processing Record 21 of Set 9 | japura
# Processing Record 22 of Set 9 | lata
# Processing Record 23 of Set 9 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 24 of Set 9 | revda
# Processing Record 25 of Set 9 | causapscal
# Processing Record 26 of Set 9 | orimattila
# Processing Record 27 of Set 9 | mayumba
# Processing Record 28 of Set 9 | talant
# Processing Record 29 of Set 9 | eureka
# Processing Record 30 of Set 9 | puerto madryn
# Processing Record 31 of Set 9 | adelaide
# Processing Record 32 of Set 9 | kemijarvi
# Processing Record 33 of Set 9 | tuatapere
# Processing Record 34 of Set 9 | mackenzie
# Processing Record 35 of Set 9 | tres arroyos
# Processing Record 36 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-joseph
# Processing Record 38 of Set 9 | orange
# Processing Record 39 of Set 9 | havre-saint-pierre
# Processing Record 40 of Set 9 | srednekolymsk
# Processing Record 41 of Set 9 | mount pleasant
# Processing Record 42 of Set 9 | oussouye
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | quelimane
# Processing Record 45 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 9 | batemans bay
# Processing Record 47 of Set 9 | riachao
# Processing Record 48 of Set 9 | mattru
# Processing Record 49 of Set 9 | lompoc
# Processing Record 0 of Set 10 | avera
# Processing Record 1 of Set 10 | gladstone
# Processing Record 2 of Set 10 | srandakan
# Processing Record 3 of Set 10 | santa cecilia
# Processing Record 4 of Set 10 | vieste
# Processing Record 5 of Set 10 | cururupu
# Processing Record 6 of Set 10 | shamsabad
# Processing Record 7 of Set 10 | kaitong
# Processing Record 8 of Set 10 | ekhabi
# Processing Record 9 of Set 10 | hinton
# Processing Record 10 of Set 10 | collie
# Processing Record 11 of Set 10 | lasa
# Processing Record 12 of Set 10 | forest hill
# Processing Record 13 of Set 10 | ixtapa
# Processing Record 14 of Set 10 | normandin
# Processing Record 15 of Set 10 | pangnirtung
# Processing Record 16 of Set 10 | thurles
# Processing Record 17 of Set 10 | mnogovershinnyy
# Processing Record 18 of Set 10 | sorong
# Processing Record 19 of Set 10 | ahuimanu
# Processing Record 20 of Set 10 | upernavik
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 23 of Set 10 | saltillo
# Processing Record 24 of Set 10 | margate
# Processing Record 25 of Set 10 | nambucca heads
# Processing Record 26 of Set 10 | charyshskoye
# Processing Record 27 of Set 10 | port shepstone
# Processing Record 28 of Set 10 | kaeo
# Processing Record 29 of Set 10 | nikolayevka
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | ancud
# Processing Record 32 of Set 10 | sangar
# Processing Record 33 of Set 10 | tevaitoa
# Processing Record 34 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 10 | mokhsogollokh
# Processing Record 36 of Set 10 | mehran
# Processing Record 37 of Set 10 | la palma
# Processing Record 38 of Set 10 | zhengjiatun
# Processing Record 39 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 10 | barabinsk
# Processing Record 41 of Set 10 | aksay
# Processing Record 42 of Set 10 | aleksandrov gay
# Processing Record 43 of Set 10 | lulea
# Processing Record 44 of Set 10 | bathsheba
# Processing Record 45 of Set 10 | phan thiet
# Processing Record 46 of Set 10 | beian
# Processing Record 47 of Set 10 | ippy
# Processing Record 48 of Set 10 | khartoum
# Processing Record 49 of Set 10 | havelock
# Processing Record 0 of Set 11 | mezen
# Processing Record 1 of Set 11 | nantucket
# Processing Record 2 of Set 11 | muli
# Processing Record 3 of Set 11 | arlit
# Processing Record 4 of Set 11 | verkhoyansk
# Processing Record 5 of Set 11 | broska
# Processing Record 6 of Set 11 | wawa
# Processing Record 7 of Set 11 | santa isabel
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | broome
# Processing Record 10 of Set 11 | hobyo
# Processing Record 11 of Set 11 | champerico
# Processing Record 12 of Set 11 | buchanan
# Processing Record 13 of Set 11 | svetlogorsk
# Processing Record 14 of Set 11 | uruzgan
# Processing Record 15 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 11 | calabozo
# Processing Record 18 of Set 11 | litovko
# Processing Record 19 of Set 11 | maniitsoq
# Processing Record 20 of Set 11 | banjar
# Processing Record 21 of Set 11 | yerofey pavlovich
# Processing Record 22 of Set 11 | shirokiy
# Processing Record 23 of Set 11 | pervomayskiy
# Processing Record 24 of Set 11 | sheltozero
# Processing Record 25 of Set 11 | kochubeyevskoye
# Processing Record 26 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 11 | sumbe
# Processing Record 29 of Set 11 | yulara
# Processing Record 30 of Set 11 | omboue
# Processing Record 31 of Set 11 | baghdad
# Processing Record 32 of Set 11 | klamath falls
# Processing Record 33 of Set 11 | big rapids
# Processing Record 34 of Set 11 | krasnoselkup
# Processing Record 35 of Set 11 | kutum
# Processing Record 36 of Set 11 | kondinskoye
# Processing Record 37 of Set 11 | rawson
# Processing Record 38 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 11 | arsenyev
# Processing Record 40 of Set 11 | tshane
# Processing Record 41 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 11 | carutapera
# Processing Record 43 of Set 11 | peace river
# Processing Record 44 of Set 11 | aras
# Processing Record 45 of Set 11 | wangaratta
# Processing Record 46 of Set 11 | carauari
# Processing Record 47 of Set 11 | changqing
# Processing Record 48 of Set 11 | chagoda
# Processing Record 49 of Set 11 | gamba
# Processing Record 0 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 12 | sibolga
# Processing Record 2 of Set 12 | chauk
# Processing Record 3 of Set 12 | lucea
# Processing Record 4 of Set 12 | taltal
# Processing Record 5 of Set 12 | belmonte
# Processing Record 6 of Set 12 | atar
# Processing Record 7 of Set 12 | saint-augustin
# Processing Record 8 of Set 12 | north bend
# Processing Record 9 of Set 12 | ola
# Processing Record 10 of Set 12 | codrington
# Processing Record 11 of Set 12 | talavera de la reina
# Processing Record 12 of Set 12 | sirjan
# Processing Record 13 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 14 of Set 12 | antalaha
# Processing Record 15 of Set 12 | mackay
# Processing Record 16 of Set 12 | ghotki
# Processing Record 17 of Set 12 | amboise
# Processing Record 18 of Set 12 | lukovetskiy
# Processing Record 19 of Set 12 | obo
# Processing Record 20 of Set 12 | somotillo
# Processing Record 21 of Set 12 | tautira
# Processing Record 22 of Set 12 | sterlibashevo
# Processing Record 23 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 24 of Set 12 | barcelos
# Processing Record 25 of Set 12 | upington
# Processing Record 26 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 12 | kiunga
# Processing Record 28 of Set 12 | ulefoss
# Processing Record 29 of Set 12 | portland
# Processing Record 30 of Set 12 | mastic beach
# Processing Record 31 of Set 12 | bodden town
# Processing Record 32 of Set 12 | salalah
# Processing Record 33 of Set 12 | rehoboth
# Processing Record 34 of Set 12 | kuldur
# Processing Record 35 of Set 12 | sao miguel do iguacu
# Processing Record 36 of Set 12 | adrar
# Processing Record 37 of Set 12 | saint-francois
# Processing Record 38 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 12 | ambon
# Processing Record 40 of Set 12 | saint-georges
# Processing Record 41 of Set 12 | beringovskiy
# Processing Record 42 of Set 12 | maningrida
# Processing Record 43 of Set 12 | xuddur
# Processing Record 44 of Set 12 | tonj
# Processing Record 45 of Set 12 | pryazha
# Processing Record 46 of Set 12 | virginia beach
# Processing Record 47 of Set 12 | albania
# Processing Record 48 of Set 12 | merauke
# Processing Record 49 of Set 12 | olga
# Processing Record 0 of Set 13 | mayya
# Processing Record 1 of Set 13 | poum
# Processing Record 2 of Set 13 | kincardine
# Processing Record 3 of Set 13 | kattivakkam
# Processing Record 4 of Set 13 | vila franca do campo
# Processing Record 5 of Set 13 | hangu
# Processing Record 6 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 13 | manica
# Processing Record 9 of Set 13 | fort nelson
# Processing Record 10 of Set 13 | komsomolskiy
# Processing Record 11 of Set 13 | sao francisco de assis
# Processing Record 12 of Set 13 | alugan
# Processing Record 13 of Set 13 | moranbah
# Processing Record 14 of Set 13 | abu samrah
# Processing Record 15 of Set 13 | andenes
# Processing Record 16 of Set 13 | samana
# Processing Record 17 of Set 13 | namibe
# Processing Record 18 of Set 13 | dongsheng
# Processing Record 19 of Set 13 | buluang
# Processing Record 20 of Set 13 | russell
# Processing Record 21 of Set 13 | rodrigues alves
# Processing Record 22 of Set 13 | luderitz
# Processing Record 23 of Set 13 | nizwa
# Processing Record 24 of Set 13 | mamallapuram
# Processing Record 25 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 13 | el alto
# Processing Record 27 of Set 13 | eirunepe
# Processing Record 28 of Set 13 | dicabisagan
# Processing Record 29 of Set 13 | khiri mat
# Processing Record 30 of Set 13 | ginir
# Processing Record 31 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 13 | gornopravdinsk
# Processing Record 33 of Set 13 | richards bay
# Processing Record 34 of Set 13 | jimenez
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        victoria  22.2855  114.1577     14.46        68          50
# 1        hermanus -34.4187   19.2345     14.33        64         100
# 2  guerrero negro  27.9769 -114.0611     20.14        63           9
# 3           vitim  59.4511  112.5578    -12.18        94         100
# 4         requena  39.4883   -1.1004      9.33        95         100
#
#    Wind Speed Country        Date
# 0        5.36      HK  1670270818
# 1        1.42      ZA  1670270813
# 2        6.74      MX  1670270982
# 3        5.78      RU  1670271381
# 4        1.49      ES  1670271381

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        victoria  22.2855  114.1577     14.46        68          50
# 1        hermanus -34.4187   19.2345     14.33        64         100
# 2  guerrero negro  27.9769 -114.0611     20.14        63           9
# 3           vitim  59.4511  112.5578    -12.18        94         100
# 4         requena  39.4883   -1.1004      9.33        95         100
#
#    Wind Speed Country        Date
# 0        5.36      HK  1670270818
# 1        1.42      ZA  1670270813
# 2        6.74      MX  1670270982
# 3        5.78      RU  1670271381
# 4        1.49      ES  1670271381

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              victoria  22.2855  114.1577     14.46        68          50
# 1              hermanus -34.4187   19.2345     14.33        64         100
# 2        guerrero negro  27.9769 -114.0611     20.14        63           9
# 3                 vitim  59.4511  112.5578    -12.18        94         100
# 4               requena  39.4883   -1.1004      9.33        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.36      HK  1670270818
# 1              1.42      ZA  1670270813
# 2              6.74      MX  1670270982
# 3              5.78      RU  1670271381
# 4              1.49      ES  1670271381

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
y_max_temp = city_data_df["Max Temp"]
x_latitude = city_data_df["Lat"]
plt.scatter(x_latitude, y_max_temp, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Max Temerature")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
y_humidity = city_data_df["Humidity"]
x_latitude = city_data_df["Lat"]
plt.scatter(x_latitude, y_humidity, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
y_cloudiness = city_data_df["Cloudiness"]
x_latitude = city_data_df["Lat"]
plt.scatter(x_latitude, y_cloudiness, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
y_wind = city_data_df["Wind Speed"]
x_latitude = city_data_df["Lat"]
plt.scatter(x_latitude, y_wind, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Create a DataFrame with the Northern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
northern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat']>= 0,:])
# Display sample data
northern_hemi_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              victoria  22.2855  114.1577     14.46        68          50
# 2        guerrero negro  27.9769 -114.0611     20.14        63           9
# 3                 vitim  59.4511  112.5578    -12.18        94         100
# 4               requena  39.4883   -1.1004      9.33        95         100
# 5                shache  38.4167   77.2406     -5.73        40           0
# ...                 ...      ...       ...       ...       ...         ...
# 570         dicabisagan  17.0818  122.4157     24.22        92         100
# 571           khiri mat  16.8333   99.8000     23.74        84          77
# 572               ginir   7.1333   40.7000     14.08        35          12
# 573      gornopravdinsk  60.0500   69.9000    -21.58       100         100
# 575             jimenez  28.3333 -105.4000     28.01        24          80
#
#          Wind Speed Country        Date
# City_ID
# 0              5.36      HK  1670270818
# 2              6.74      MX  1670270982
# 3              5.78      RU  1670271381
# 4              1.49      ES  1670271381
# 5              1.16      CN  1670270961
# ...             ...     ...         ...
# 570            3.16      PH  1670271600
# 571            0.65      TH  1670271601
# 572            2.38      ET  1670271601
# 573            1.32      RU  1670271602
# 575            4.93      MX  1670271454
#
# [393 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat']< 0,:])
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            hermanus -34.4187   19.2345     14.33        64         100
# 8        puerto ayora  -0.7393  -90.3518     24.98        87          64
# 9             mataura -46.1927  168.8643     10.27        99         100
# 10            rikitea -23.1203 -134.9692     24.15        81          99
# 12        east london -33.0153   27.9116     16.34        83           4
#
#          Wind Speed Country        Date
# City_ID
# 1              1.42      ZA  1670270813
# 8              2.68      EC  1670270867
# 9              1.16      NZ  1670270824
# 10             6.37      PF  1670270814
# 12             4.34      ZA  1670270912

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,-10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
